# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list

coordinates = list(lat_lngs)

print(len(coordinates))
# Out:
# 2000

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(len(cities))
# Out:
# 775

# %%
limit = 5

for i, city in enumerate(cities):
    print(city.title())
    if i == limit:
        break
# Out:
# Sinjar
# Bluff
# Belushya Guba
# Iqaluit
# Port Elizabeth
# Avera

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
city_data = []

city_url = 'http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5442fd638afefd7384a37fa32a1e93d&q=hohhot'
city_weather = requests.get(city_url).json()

print(city_weather)

city_lat = city_weather["coord"]["lat"]
print(city_lat)
city_lng = city_weather["coord"]["lon"]
print(city_lng)
city_max_temp = city_weather["main"]["temp_max"]
print(city_max_temp)
city_humidity = city_weather["main"]["humidity"]
city_clouds = city_weather["clouds"]["all"]
print(city_clouds)
city_wind = city_weather["wind"]["speed"]
city_country = city_weather["sys"]["country"]
city_weather_desc = city_weather["weather"][0]["description"]
print(city_weather_desc)

city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Weather Description": city_weather_desc})

print(city_data)
# Out:
# {'coord': {'lon': 111.6522, 'lat': 40.8106}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 39.49, 'feels_like': 36.3, 'temp_min': 39.49, 'temp_max': 39.49, 'pressure': 1029, 'humidity': 35}, 'visibility': 10000, 'wind': {'speed': 4.47, 'deg': 190}, 'clouds': {'all': 0}, 'dt': 1667183578, 'sys': {'type': 1, 'id': 9612, 'country': 'CN', 'sunrise': 1667170920, 'sunset': 1667208713}, 'timezone': 28800, 'id': 2036892, 'name': 'Hohhot', 'cod': 200}
# 40.8106
# 111.6522
# 39.49
# 0
# clear sky
# [{'City': 'Avera', 'Lat': 40.8106, 'Lng': 111.6522, 'Max Temp': 39.49, 'Humidity': 35, 'Cloudiness': 0, 'Wind Speed': 4.47, 'Country': 'CN', 'Weather Description': 'clear sky'}]

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_desc = city_weather["weather"][0]["description"]
            
        #Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Weather Description": city_weather_desc})
        
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | sinjar
# Processing Record 2 of Set 1 | bluff
# Processing Record 3 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 4 of Set 1 | iqaluit
# Processing Record 5 of Set 1 | port elizabeth
# Processing Record 6 of Set 1 | avera
# Processing Record 7 of Set 1 | linchuan
# City not found. Skipping...
# Processing Record 8 of Set 1 | hilo
# Processing Record 9 of Set 1 | masvingo
# Processing Record 10 of Set 1 | uvira
# Processing Record 11 of Set 1 | takoradi
# Processing Record 12 of Set 1 | pevek
# Processing Record 13 of Set 1 | kapaa
# Processing Record 14 of Set 1 | bredasdorp
# Processing Record 15 of Set 1 | new milford
# Processing Record 16 of Set 1 | hermanus
# Processing Record 17 of Set 1 | puerto ayora
# Processing Record 18 of Set 1 | nola
# Processing Record 19 of Set 1 | albany
# Processing Record 20 of Set 1 | ngukurr
# City not found. Skipping...
# Processing Record 21 of Set 1 | bandarbeyla
# Processing Record 22 of Set 1 | saldanha
# Processing Record 23 of Set 1 | torbay
# Processing Record 24 of Set 1 | cape town
# Processing Record 25 of Set 1 | bethel
# Processing Record 26 of Set 1 | vaini
# Processing Record 27 of Set 1 | ribeira grande
# Processing Record 28 of Set 1 | busselton
# Processing Record 29 of Set 1 | poum
# Processing Record 30 of Set 1 | arcachon
# Processing Record 31 of Set 1 | dikson
# Processing Record 32 of Set 1 | terney
# Processing Record 33 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 34 of Set 1 | saint-louis
# Processing Record 35 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 36 of Set 1 | tuktoyaktuk
# Processing Record 37 of Set 1 | ponta do sol
# Processing Record 38 of Set 1 | jiddah
# City not found. Skipping...
# Processing Record 39 of Set 1 | airai
# Processing Record 40 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 41 of Set 1 | vostok
# Processing Record 42 of Set 1 | kruisfontein
# Processing Record 43 of Set 1 | saint-philippe
# Processing Record 44 of Set 1 | ozd
# Processing Record 45 of Set 1 | porgera
# Processing Record 46 of Set 1 | butaritari
# Processing Record 47 of Set 1 | mataura
# Processing Record 48 of Set 1 | chokurdakh
# Processing Record 49 of Set 1 | avarua
# Processing Record 50 of Set 1 | rikitea
# Processing Record 1 of Set 2 | muros
# Processing Record 2 of Set 2 | ushuaia
# Processing Record 3 of Set 2 | arraial do cabo
# Processing Record 4 of Set 2 | punta arenas
# Processing Record 5 of Set 2 | vanavara
# Processing Record 6 of Set 2 | muroto
# Processing Record 7 of Set 2 | chuy
# Processing Record 8 of Set 2 | port alfred
# Processing Record 9 of Set 2 | jamestown
# Processing Record 10 of Set 2 | lompoc
# Processing Record 11 of Set 2 | sao joao da barra
# Processing Record 12 of Set 2 | mantua
# Processing Record 13 of Set 2 | nishihara
# Processing Record 14 of Set 2 | eydhafushi
# Processing Record 15 of Set 2 | faanui
# Processing Record 16 of Set 2 | okha
# Processing Record 17 of Set 2 | mayo
# Processing Record 18 of Set 2 | nurota
# Processing Record 19 of Set 2 | ancud
# Processing Record 20 of Set 2 | debre tabor
# Processing Record 21 of Set 2 | hokitika
# Processing Record 22 of Set 2 | champerico
# Processing Record 23 of Set 2 | arlit
# Processing Record 24 of Set 2 | khatanga
# Processing Record 25 of Set 2 | georgetown
# Processing Record 26 of Set 2 | faya
# Processing Record 27 of Set 2 | broome
# Processing Record 28 of Set 2 | vardo
# Processing Record 29 of Set 2 | alyangula
# Processing Record 30 of Set 2 | oltu
# Processing Record 31 of Set 2 | yenagoa
# Processing Record 32 of Set 2 | amos
# Processing Record 33 of Set 2 | rawson
# Processing Record 34 of Set 2 | kaitangata
# Processing Record 35 of Set 2 | porto novo
# Processing Record 36 of Set 2 | touros
# Processing Record 37 of Set 2 | cherskiy
# Processing Record 38 of Set 2 | namatanai
# Processing Record 39 of Set 2 | gulu
# Processing Record 40 of Set 2 | padang
# Processing Record 41 of Set 2 | coquimbo
# Processing Record 42 of Set 2 | saint george
# Processing Record 43 of Set 2 | kununurra
# Processing Record 44 of Set 2 | vila velha
# Processing Record 45 of Set 2 | kavieng
# Processing Record 46 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 47 of Set 2 | hambantota
# Processing Record 48 of Set 2 | saint-francois
# Processing Record 49 of Set 2 | valdivia
# Processing Record 50 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 1 of Set 3 | hobart
# Processing Record 2 of Set 3 | mahebourg
# Processing Record 3 of Set 3 | dicabisagan
# Processing Record 4 of Set 3 | tasiilaq
# Processing Record 5 of Set 3 | kloulklubed
# Processing Record 6 of Set 3 | high river
# Processing Record 7 of Set 3 | mareeba
# Processing Record 8 of Set 3 | chulym
# Processing Record 9 of Set 3 | bambanglipuro
# Processing Record 10 of Set 3 | zhitikara
# City not found. Skipping...
# Processing Record 11 of Set 3 | bambous virieux
# Processing Record 12 of Set 3 | tunghsiao
# City not found. Skipping...
# Processing Record 13 of Set 3 | pacifica
# Processing Record 14 of Set 3 | kachikau
# City not found. Skipping...
# Processing Record 15 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 16 of Set 3 | qaanaaq
# Processing Record 17 of Set 3 | sakakah
# Processing Record 18 of Set 3 | yerofey pavlovich
# Processing Record 19 of Set 3 | codrington
# Processing Record 20 of Set 3 | bengkulu
# Processing Record 21 of Set 3 | clyde river
# Processing Record 22 of Set 3 | paradwip
# City not found. Skipping...
# Processing Record 23 of Set 3 | san cristobal
# Processing Record 24 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 25 of Set 3 | hithadhoo
# Processing Record 26 of Set 3 | new norfolk
# Processing Record 27 of Set 3 | nikolskoye
# Processing Record 28 of Set 3 | norman wells
# Processing Record 29 of Set 3 | bazarnyy syzgan
# Processing Record 30 of Set 3 | castro
# Processing Record 31 of Set 3 | kahului
# Processing Record 32 of Set 3 | sobolevo
# Processing Record 33 of Set 3 | jinchang
# Processing Record 34 of Set 3 | adrar
# Processing Record 35 of Set 3 | khandyga
# Processing Record 36 of Set 3 | waipawa
# Processing Record 37 of Set 3 | karratha
# Processing Record 38 of Set 3 | farkhor
# Processing Record 39 of Set 3 | amapa
# Processing Record 40 of Set 3 | tiksi
# Processing Record 41 of Set 3 | farafangana
# Processing Record 42 of Set 3 | east london
# Processing Record 43 of Set 3 | eaton socon
# Processing Record 44 of Set 3 | kieta
# Processing Record 45 of Set 3 | tuatapere
# Processing Record 46 of Set 3 | nizwa
# Processing Record 47 of Set 3 | seguin
# Processing Record 48 of Set 3 | scottsbluff
# Processing Record 49 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 50 of Set 3 | karistos
# City not found. Skipping...
# Processing Record 1 of Set 4 | comodoro rivadavia
# Processing Record 2 of Set 4 | talnakh
# Processing Record 3 of Set 4 | pangnirtung
# Processing Record 4 of Set 4 | nabire
# Processing Record 5 of Set 4 | mount isa
# Processing Record 6 of Set 4 | barrow
# Processing Record 7 of Set 4 | yulara
# Processing Record 8 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 9 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 10 of Set 4 | salalah
# Processing Record 11 of Set 4 | vila
# Processing Record 12 of Set 4 | san lorenzo
# Processing Record 13 of Set 4 | san jeronimo
# Processing Record 14 of Set 4 | antalaha
# Processing Record 15 of Set 4 | margate
# Processing Record 16 of Set 4 | easton
# Processing Record 17 of Set 4 | roald
# Processing Record 18 of Set 4 | sao francisco do sul
# Processing Record 19 of Set 4 | cockburn town
# Processing Record 20 of Set 4 | atuona
# Processing Record 21 of Set 4 | cansancao
# Processing Record 22 of Set 4 | labuhan
# Processing Record 23 of Set 4 | saskylakh
# Processing Record 24 of Set 4 | harper
# Processing Record 25 of Set 4 | chicama
# Processing Record 26 of Set 4 | zhigansk
# Processing Record 27 of Set 4 | saint-joseph
# Processing Record 28 of Set 4 | laguna
# Processing Record 29 of Set 4 | ambon
# Processing Record 30 of Set 4 | aripuana
# Processing Record 31 of Set 4 | homer
# Processing Record 32 of Set 4 | boffa
# Processing Record 33 of Set 4 | moengo
# Processing Record 34 of Set 4 | rodrigues alves
# Processing Record 35 of Set 4 | songjianghe
# Processing Record 36 of Set 4 | inirida
# Processing Record 37 of Set 4 | bonthe
# Processing Record 38 of Set 4 | ucluelet
# Processing Record 39 of Set 4 | coolum beach
# Processing Record 40 of Set 4 | mar del plata
# Processing Record 41 of Set 4 | orlik
# Processing Record 42 of Set 4 | gwadar
# Processing Record 43 of Set 4 | ugoofaaru
# Processing Record 44 of Set 4 | yuzhnyy
# Processing Record 45 of Set 4 | aswan
# Processing Record 46 of Set 4 | kindu
# Processing Record 47 of Set 4 | kokstad
# Processing Record 48 of Set 4 | agutaya
# Processing Record 49 of Set 4 | metro
# Processing Record 50 of Set 4 | zhaodong
# Processing Record 1 of Set 5 | hun
# Processing Record 2 of Set 5 | victoria
# Processing Record 3 of Set 5 | esna
# Processing Record 4 of Set 5 | mogadishu
# Processing Record 5 of Set 5 | husavik
# Processing Record 6 of Set 5 | provideniya
# Processing Record 7 of Set 5 | axim
# Processing Record 8 of Set 5 | aykhal
# Processing Record 9 of Set 5 | leshukonskoye
# Processing Record 10 of Set 5 | cabo san lucas
# Processing Record 11 of Set 5 | cidreira
# Processing Record 12 of Set 5 | flinders
# Processing Record 13 of Set 5 | caravelas
# Processing Record 14 of Set 5 | nome
# Processing Record 15 of Set 5 | porto nacional
# Processing Record 16 of Set 5 | rungata
# City not found. Skipping...
# Processing Record 17 of Set 5 | olafsvik
# Processing Record 18 of Set 5 | kamenka
# Processing Record 19 of Set 5 | halalo
# City not found. Skipping...
# Processing Record 20 of Set 5 | letterkenny
# Processing Record 21 of Set 5 | mahon
# Processing Record 22 of Set 5 | aguimes
# Processing Record 23 of Set 5 | don benito
# Processing Record 24 of Set 5 | shangzhi
# Processing Record 25 of Set 5 | tulun
# Processing Record 26 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 27 of Set 5 | lebu
# Processing Record 28 of Set 5 | sioux lookout
# Processing Record 29 of Set 5 | te anau
# Processing Record 30 of Set 5 | ereymentau
# Processing Record 31 of Set 5 | yar-sale
# Processing Record 32 of Set 5 | marsh harbour
# Processing Record 33 of Set 5 | erzin
# Processing Record 34 of Set 5 | achutupo
# Processing Record 35 of Set 5 | pisco
# Processing Record 36 of Set 5 | mana
# Processing Record 37 of Set 5 | cerrito
# Processing Record 38 of Set 5 | mmabatho
# Processing Record 39 of Set 5 | matara
# Processing Record 40 of Set 5 | chaman
# Processing Record 41 of Set 5 | saveh
# Processing Record 42 of Set 5 | nanortalik
# Processing Record 43 of Set 5 | burnie
# Processing Record 44 of Set 5 | egvekinot
# Processing Record 45 of Set 5 | yellowknife
# Processing Record 46 of Set 5 | manggar
# Processing Record 47 of Set 5 | labutta
# City not found. Skipping...
# Processing Record 48 of Set 5 | narsaq
# Processing Record 49 of Set 5 | kita
# Processing Record 50 of Set 5 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 1 of Set 6 | vanimo
# Processing Record 2 of Set 6 | nardaran
# Processing Record 3 of Set 6 | tubmanburg
# Processing Record 4 of Set 6 | seoul
# Processing Record 5 of Set 6 | flin flon
# Processing Record 6 of Set 6 | fort myers beach
# Processing Record 7 of Set 6 | sechura
# Processing Record 8 of Set 6 | nagram
# Processing Record 9 of Set 6 | tessalit
# Processing Record 10 of Set 6 | udachnyy
# Processing Record 11 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 12 of Set 6 | berdigestyakh
# Processing Record 13 of Set 6 | portree
# Processing Record 14 of Set 6 | fruitville
# Processing Record 15 of Set 6 | dingle
# Processing Record 16 of Set 6 | lorengau
# Processing Record 17 of Set 6 | anadyr
# Processing Record 18 of Set 6 | nautla
# Processing Record 19 of Set 6 | henties bay
# Processing Record 20 of Set 6 | lazaro cardenas
# Processing Record 21 of Set 6 | leningradskiy
# Processing Record 22 of Set 6 | muravlenko
# Processing Record 23 of Set 6 | sitka
# Processing Record 24 of Set 6 | souillac
# Processing Record 25 of Set 6 | butzow
# Processing Record 26 of Set 6 | ngunguru
# Processing Record 27 of Set 6 | beloha
# Processing Record 28 of Set 6 | vanino
# Processing Record 29 of Set 6 | borger
# Processing Record 30 of Set 6 | grootfontein
# Processing Record 31 of Set 6 | thanatpin
# Processing Record 32 of Set 6 | bathsheba
# Processing Record 33 of Set 6 | bilibino
# Processing Record 34 of Set 6 | nguiu
# City not found. Skipping...
# Processing Record 35 of Set 6 | berlevag
# Processing Record 36 of Set 6 | mackay
# Processing Record 37 of Set 6 | karakose
# City not found. Skipping...
# Processing Record 38 of Set 6 | sept-iles
# Processing Record 39 of Set 6 | leninskoye
# Processing Record 40 of Set 6 | nova olimpia
# Processing Record 41 of Set 6 | sabzevar
# Processing Record 42 of Set 6 | isangel
# Processing Record 43 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 44 of Set 6 | mazarron
# Processing Record 45 of Set 6 | dese
# Processing Record 46 of Set 6 | ixtapa
# Processing Record 47 of Set 6 | mutsu
# Processing Record 48 of Set 6 | leh
# Processing Record 49 of Set 6 | lac du bonnet
# Processing Record 50 of Set 6 | peniche
# Processing Record 1 of Set 7 | dunedin
# Processing Record 2 of Set 7 | thunder bay
# Processing Record 3 of Set 7 | hearst
# Processing Record 4 of Set 7 | sambava
# Processing Record 5 of Set 7 | sabang
# Processing Record 6 of Set 7 | baboua
# City not found. Skipping...
# Processing Record 7 of Set 7 | presidencia roque saenz pena
# Processing Record 8 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 9 of Set 7 | kyabram
# Processing Record 10 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 11 of Set 7 | bardiyah
# Processing Record 12 of Set 7 | constitucion
# Processing Record 13 of Set 7 | montepuez
# Processing Record 14 of Set 7 | luxor
# Processing Record 15 of Set 7 | san patricio
# Processing Record 16 of Set 7 | langedijk
# Processing Record 17 of Set 7 | siaya
# Processing Record 18 of Set 7 | abu jubayhah
# City not found. Skipping...
# Processing Record 19 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 20 of Set 7 | bara
# Processing Record 21 of Set 7 | khudumelapye
# Processing Record 22 of Set 7 | hami
# Processing Record 23 of Set 7 | namtsy
# Processing Record 24 of Set 7 | klerksdorp
# Processing Record 25 of Set 7 | sladkovo
# Processing Record 26 of Set 7 | reo
# Processing Record 27 of Set 7 | lar gerd
# City not found. Skipping...
# Processing Record 28 of Set 7 | caibarien
# Processing Record 29 of Set 7 | bagan
# Processing Record 30 of Set 7 | vaitape
# Processing Record 31 of Set 7 | kajaani
# Processing Record 32 of Set 7 | salemi
# Processing Record 33 of Set 7 | richards bay
# Processing Record 34 of Set 7 | lata
# Processing Record 35 of Set 7 | santa maria
# Processing Record 36 of Set 7 | merauke
# Processing Record 37 of Set 7 | mentok
# City not found. Skipping...
# Processing Record 38 of Set 7 | mwinilunga
# Processing Record 39 of Set 7 | palmer
# Processing Record 40 of Set 7 | kavaratti
# Processing Record 41 of Set 7 | darnah
# Processing Record 42 of Set 7 | heubach
# Processing Record 43 of Set 7 | yomitan
# City not found. Skipping...
# Processing Record 44 of Set 7 | bayanday
# Processing Record 45 of Set 7 | morristown
# Processing Record 46 of Set 7 | kwinana
# Processing Record 47 of Set 7 | atambua
# Processing Record 48 of Set 7 | tautira
# Processing Record 49 of Set 7 | nuuk
# Processing Record 50 of Set 7 | severo-kurilsk
# Processing Record 1 of Set 8 | sao filipe
# Processing Record 2 of Set 8 | katsuura
# Processing Record 3 of Set 8 | kysyl-syr
# Processing Record 4 of Set 8 | nampula
# Processing Record 5 of Set 8 | pipri
# Processing Record 6 of Set 8 | lavrentiya
# Processing Record 7 of Set 8 | gap
# Processing Record 8 of Set 8 | ulladulla
# Processing Record 9 of Set 8 | okhotsk
# Processing Record 10 of Set 8 | westport
# Processing Record 11 of Set 8 | jhargram
# Processing Record 12 of Set 8 | solnechnyy
# Processing Record 13 of Set 8 | longyearbyen
# Processing Record 14 of Set 8 | arman
# Processing Record 15 of Set 8 | prince george
# Processing Record 16 of Set 8 | sao gotardo
# Processing Record 17 of Set 8 | la libertad
# Processing Record 18 of Set 8 | carnarvon
# Processing Record 19 of Set 8 | karkaralinsk
# City not found. Skipping...
# Processing Record 20 of Set 8 | mukdahan
# Processing Record 21 of Set 8 | puerto palomas
# Processing Record 22 of Set 8 | tartagal
# Processing Record 23 of Set 8 | shelburne
# Processing Record 24 of Set 8 | khonuu
# City not found. Skipping...
# Processing Record 25 of Set 8 | villazon
# Processing Record 26 of Set 8 | wanning
# Processing Record 27 of Set 8 | manono
# Processing Record 28 of Set 8 | voyvozh
# Processing Record 29 of Set 8 | saint-augustin
# Processing Record 30 of Set 8 | thompson
# Processing Record 31 of Set 8 | alofi
# Processing Record 32 of Set 8 | kutum
# Processing Record 33 of Set 8 | kurumkan
# Processing Record 34 of Set 8 | bombay
# Processing Record 35 of Set 8 | williston
# Processing Record 36 of Set 8 | ilulissat
# Processing Record 37 of Set 8 | ituni
# City not found. Skipping...
# Processing Record 38 of Set 8 | port blair
# Processing Record 39 of Set 8 | manicore
# Processing Record 40 of Set 8 | jacareacanga
# Processing Record 41 of Set 8 | fukumitsu
# Processing Record 42 of Set 8 | galesong
# Processing Record 43 of Set 8 | pregassona
# Processing Record 44 of Set 8 | smithers
# Processing Record 45 of Set 8 | soeng sang
# Processing Record 46 of Set 8 | marawi
# Processing Record 47 of Set 8 | seidu
# Processing Record 48 of Set 8 | yumen
# Processing Record 49 of Set 8 | parintins
# Processing Record 50 of Set 8 | saint anthony
# Processing Record 1 of Set 9 | port hedland
# Processing Record 2 of Set 9 | beringovskiy
# Processing Record 3 of Set 9 | markova
# Processing Record 4 of Set 9 | kazalinsk
# City not found. Skipping...
# Processing Record 5 of Set 9 | oissel
# Processing Record 6 of Set 9 | sao felix do xingu
# Processing Record 7 of Set 9 | havoysund
# Processing Record 8 of Set 9 | qaqortoq
# Processing Record 9 of Set 9 | mercedes
# Processing Record 10 of Set 9 | raudeberg
# Processing Record 11 of Set 9 | hay river
# Processing Record 12 of Set 9 | xiaoshi
# Processing Record 13 of Set 9 | lahaina
# Processing Record 14 of Set 9 | shingu
# Processing Record 15 of Set 9 | kayerkan
# Processing Record 16 of Set 9 | meulaboh
# Processing Record 17 of Set 9 | litovko
# Processing Record 18 of Set 9 | lagoa
# Processing Record 19 of Set 9 | pandamatenga
# Processing Record 20 of Set 9 | mapiripan
# Processing Record 21 of Set 9 | puerto madero
# Processing Record 22 of Set 9 | sao mateus do sul
# Processing Record 23 of Set 9 | san quintin
# Processing Record 24 of Set 9 | rio gallegos
# Processing Record 25 of Set 9 | atar
# Processing Record 26 of Set 9 | half moon bay
# Processing Record 27 of Set 9 | carmen
# Processing Record 28 of Set 9 | monopoli
# Processing Record 29 of Set 9 | itacoatiara
# Processing Record 30 of Set 9 | kipini
# Processing Record 31 of Set 9 | kamennogorsk
# Processing Record 32 of Set 9 | koslan
# Processing Record 33 of Set 9 | geraldton
# Processing Record 34 of Set 9 | antofagasta
# Processing Record 35 of Set 9 | lumphat
# Processing Record 36 of Set 9 | bonoua
# Processing Record 37 of Set 9 | ambilobe
# Processing Record 38 of Set 9 | bhatkal
# Processing Record 39 of Set 9 | riviere-au-renard
# Processing Record 40 of Set 9 | paamiut
# Processing Record 41 of Set 9 | cayenne
# Processing Record 42 of Set 9 | upernavik
# Processing Record 43 of Set 9 | dubbo
# Processing Record 44 of Set 9 | payo
# Processing Record 45 of Set 9 | anjar
# Processing Record 46 of Set 9 | tromso
# Processing Record 47 of Set 9 | sahrak
# City not found. Skipping...
# Processing Record 48 of Set 9 | afanasyevo
# City not found. Skipping...
# Processing Record 49 of Set 9 | katakwi
# Processing Record 50 of Set 9 | hasaki
# Processing Record 1 of Set 10 | san jose
# Processing Record 2 of Set 10 | kodiak
# Processing Record 3 of Set 10 | palu
# Processing Record 4 of Set 10 | sao goncalo do sapucai
# Processing Record 5 of Set 10 | palembang
# Processing Record 6 of Set 10 | awjilah
# Processing Record 7 of Set 10 | lasa
# Processing Record 8 of Set 10 | artesia
# Processing Record 9 of Set 10 | tomatlan
# Processing Record 10 of Set 10 | bo rai
# Processing Record 11 of Set 10 | srednekolymsk
# Processing Record 12 of Set 10 | miri
# Processing Record 13 of Set 10 | tieli
# Processing Record 14 of Set 10 | siguiri
# Processing Record 15 of Set 10 | russell
# Processing Record 16 of Set 10 | port lincoln
# Processing Record 17 of Set 10 | hohhot
# Processing Record 18 of Set 10 | roi et
# Processing Record 19 of Set 10 | dataganj
# Processing Record 20 of Set 10 | wanxian
# Processing Record 21 of Set 10 | farsund
# Processing Record 22 of Set 10 | ferme-neuve
# Processing Record 23 of Set 10 | soyo
# Processing Record 24 of Set 10 | yerbogachen
# Processing Record 25 of Set 10 | saryg-sep
# Processing Record 26 of Set 10 | tangzhai
# Processing Record 27 of Set 10 | iguape
# Processing Record 28 of Set 10 | iskar
# Processing Record 29 of Set 10 | jiroft
# City not found. Skipping...
# Processing Record 30 of Set 10 | soe
# Processing Record 31 of Set 10 | howard springs
# Processing Record 32 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 33 of Set 10 | fairbanks
# Processing Record 34 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 35 of Set 10 | oranjemund
# Processing Record 36 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 37 of Set 10 | port hardy
# Processing Record 38 of Set 10 | coihaique
# Processing Record 39 of Set 10 | piacabucu
# Processing Record 40 of Set 10 | sovetskoye
# Processing Record 41 of Set 10 | talaya
# Processing Record 42 of Set 10 | fort nelson
# Processing Record 43 of Set 10 | kandri
# Processing Record 44 of Set 10 | celestun
# Processing Record 45 of Set 10 | asekeyevo
# Processing Record 46 of Set 10 | riyadh
# Processing Record 47 of Set 10 | mulege
# Processing Record 48 of Set 10 | lewiston
# Processing Record 49 of Set 10 | los algarrobos
# Processing Record 50 of Set 10 | tres arroyos
# Processing Record 1 of Set 11 | baleshwar
# Processing Record 2 of Set 11 | cassilandia
# Processing Record 3 of Set 11 | klaksvik
# Processing Record 4 of Set 11 | zlobin
# Processing Record 5 of Set 11 | valparaiso
# Processing Record 6 of Set 11 | fortuna
# Processing Record 7 of Set 11 | bokspits
# City not found. Skipping...
# Processing Record 8 of Set 11 | youghal
# Processing Record 9 of Set 11 | hobyo
# Processing Record 10 of Set 11 | grand gaube
# Processing Record 11 of Set 11 | ambodifototra
# City not found. Skipping...
# Processing Record 12 of Set 11 | hangu
# Processing Record 13 of Set 11 | saint-jean-de-maurienne
# Processing Record 14 of Set 11 | shimoda
# Processing Record 15 of Set 11 | rassvet
# Processing Record 16 of Set 11 | christchurch
# Processing Record 17 of Set 11 | tete
# Processing Record 18 of Set 11 | baiyin
# Processing Record 19 of Set 11 | amderma
# City not found. Skipping...
# Processing Record 20 of Set 11 | bogorodskoye
# Processing Record 21 of Set 11 | kyra
# Processing Record 22 of Set 11 | spasskoye
# Processing Record 23 of Set 11 | naze
# Processing Record 24 of Set 11 | puntarenas
# Processing Record 25 of Set 11 | el alto
# Processing Record 26 of Set 11 | hamilton
# Processing Record 27 of Set 11 | karamea
# City not found. Skipping...
# Processing Record 28 of Set 11 | oussouye
# Processing Record 29 of Set 11 | ostersund
# Processing Record 30 of Set 11 | barmer
# Processing Record 31 of Set 11 | arroyo
# Processing Record 32 of Set 11 | preobrazheniye
# Processing Record 33 of Set 11 | eureka
# Processing Record 34 of Set 11 | manta
# Processing Record 35 of Set 11 | mount gambier
# Processing Record 36 of Set 11 | walvis bay
# Processing Record 37 of Set 11 | zyryanovsk
# Processing Record 38 of Set 11 | vestmannaeyjar
# Processing Record 39 of Set 11 | grand-santi
# Processing Record 40 of Set 11 | vanderhoof
# Processing Record 41 of Set 11 | daska
# Processing Record 42 of Set 11 | sisimiut
# Processing Record 43 of Set 11 | chirongui
# Processing Record 44 of Set 11 | filadelfia
# Processing Record 45 of Set 11 | mangrol
# Processing Record 46 of Set 11 | grindavik
# Processing Record 47 of Set 11 | saint-georges
# Processing Record 48 of Set 11 | kawana waters
# City not found. Skipping...
# Processing Record 49 of Set 11 | peterhead
# Processing Record 50 of Set 11 | havre-saint-pierre
# Processing Record 1 of Set 12 | naranjal
# Processing Record 2 of Set 12 | pedernales
# Processing Record 3 of Set 12 | shalinskoye
# Processing Record 4 of Set 12 | fuyang
# Processing Record 5 of Set 12 | broken hill
# Processing Record 6 of Set 12 | poso
# Processing Record 7 of Set 12 | mogwase
# Processing Record 8 of Set 12 | honningsvag
# Processing Record 9 of Set 12 | ishigaki
# Processing Record 10 of Set 12 | yarmouth
# Processing Record 11 of Set 12 | longlac
# City not found. Skipping...
# Processing Record 12 of Set 12 | tasbuget
# City not found. Skipping...
# Processing Record 13 of Set 12 | prince rupert
# Processing Record 14 of Set 12 | lahat
# Processing Record 15 of Set 12 | fereydun kenar
# Processing Record 16 of Set 12 | hornepayne
# Processing Record 17 of Set 12 | nakambala
# Processing Record 18 of Set 12 | bundaberg
# Processing Record 19 of Set 12 | hopkinsville
# Processing Record 20 of Set 12 | mubi
# Processing Record 21 of Set 12 | armacao dos buzios
# City not found. Skipping...
# Processing Record 22 of Set 12 | povenets
# Processing Record 23 of Set 12 | neiafu
# Processing Record 24 of Set 12 | aksarka
# Processing Record 25 of Set 12 | vila franca do campo
# Processing Record 26 of Set 12 | huarmey
# Processing Record 27 of Set 12 | luderitz
# Processing Record 28 of Set 12 | smirnykh
# Processing Record 29 of Set 12 | luba
# Processing Record 30 of Set 12 | san andres
# Processing Record 31 of Set 12 | tiznit
# Processing Record 32 of Set 12 | spring hill
# Processing Record 33 of Set 12 | ballangen
# Processing Record 34 of Set 12 | denpasar
# Processing Record 35 of Set 12 | uwayl
# City not found. Skipping...
# Processing Record 36 of Set 12 | morondava
# Processing Record 37 of Set 12 | porbandar
# Processing Record 38 of Set 12 | kadom
# Processing Record 39 of Set 12 | brae
# Processing Record 40 of Set 12 | lethem
# Processing Record 41 of Set 12 | la rioja
# Processing Record 42 of Set 12 | sataua
# City not found. Skipping...
# Processing Record 43 of Set 12 | lincoln
# Processing Record 44 of Set 12 | ankazobe
# Processing Record 45 of Set 12 | cermik
# Processing Record 46 of Set 12 | tineo
# Processing Record 47 of Set 12 | lengshuitan
# Processing Record 48 of Set 12 | hofn
# Processing Record 49 of Set 12 | sfantu gheorghe
# Processing Record 50 of Set 12 | eldikan
# City not found. Skipping...
# Processing Record 1 of Set 13 | eyl
# Processing Record 2 of Set 13 | angoche
# Processing Record 3 of Set 13 | tarapur
# Processing Record 4 of Set 13 | forestville
# Processing Record 5 of Set 13 | muli
# Processing Record 6 of Set 13 | nelson bay
# Processing Record 7 of Set 13 | kingaroy
# Processing Record 8 of Set 13 | isabela
# Processing Record 9 of Set 13 | ossora
# Processing Record 10 of Set 13 | winslow
# Processing Record 11 of Set 13 | polyarnyy
# Processing Record 12 of Set 13 | kuressaare
# Processing Record 13 of Set 13 | necochea
# Processing Record 14 of Set 13 | sao jose da coroa grande
# Processing Record 15 of Set 13 | tezu
# Processing Record 16 of Set 13 | kashi
# Processing Record 17 of Set 13 | am timan
# Processing Record 18 of Set 13 | polunochnoye
# Processing Record 19 of Set 13 | krasnyye baki
# Processing Record 20 of Set 13 | emerald
# Processing Record 21 of Set 13 | zharkovskiy
# Processing Record 22 of Set 13 | kandrian
# Processing Record 23 of Set 13 | sinnamary
# Processing Record 24 of Set 13 | alotau
# City not found. Skipping...
# Processing Record 25 of Set 13 | terra santa
# Processing Record 26 of Set 13 | jerusalem
# Processing Record 27 of Set 13 | anzoategui
# Processing Record 28 of Set 13 | chifeng
# Processing Record 29 of Set 13 | elk plain
# Processing Record 30 of Set 13 | konispol
# Processing Record 31 of Set 13 | san rafael
# Processing Record 32 of Set 13 | olinda
# Processing Record 33 of Set 13 | batagay-alyta
# Processing Record 34 of Set 13 | igualada
# Processing Record 35 of Set 13 | bahawalpur
# Processing Record 36 of Set 13 | xining
# Processing Record 37 of Set 13 | oudtshoorn
# Processing Record 38 of Set 13 | gurun
# Processing Record 39 of Set 13 | baie-comeau
# Processing Record 40 of Set 13 | sinop
# Processing Record 41 of Set 13 | quatre cocos
# Processing Record 42 of Set 13 | irricana
# Processing Record 43 of Set 13 | kokopo
# Processing Record 44 of Set 13 | lebedinyy
# Processing Record 45 of Set 13 | paraiso
# Processing Record 46 of Set 13 | maghama
# City not found. Skipping...
# Processing Record 47 of Set 13 | surgut
# Processing Record 48 of Set 13 | pachino
# Processing Record 49 of Set 13 | laje
# Processing Record 50 of Set 13 | plettenberg bay
# Processing Record 1 of Set 14 | cap malheureux
# Processing Record 2 of Set 14 | evensk
# Processing Record 3 of Set 14 | ofaqim
# Processing Record 4 of Set 14 | camacha
# Processing Record 5 of Set 14 | jiazi
# Processing Record 6 of Set 14 | seymchan
# Processing Record 7 of Set 14 | vysokogornyy
# Processing Record 8 of Set 14 | colares
# Processing Record 9 of Set 14 | tuy hoa
# Processing Record 10 of Set 14 | aliwal north
# Processing Record 11 of Set 14 | yining
# Processing Record 12 of Set 14 | pitimbu
# Processing Record 13 of Set 14 | huilong
# Processing Record 14 of Set 14 | yelizovo
# Processing Record 15 of Set 14 | hovd
# Processing Record 16 of Set 14 | maragogi
# Processing Record 17 of Set 14 | uk
# City not found. Skipping...
# Processing Record 18 of Set 14 | mporokoso
# Processing Record 19 of Set 14 | namibe
# Processing Record 20 of Set 14 | ust-kut
# Processing Record 21 of Set 14 | caxito
# Processing Record 22 of Set 14 | zabol
# Processing Record 23 of Set 14 | itarema
# Processing Record 24 of Set 14 | islamkot
# Processing Record 25 of Set 14 | carbondale
# Processing Record 26 of Set 14 | karaidel
# Processing Record 27 of Set 14 | aktash
# Processing Record 28 of Set 14 | verkhoyansk
# Processing Record 29 of Set 14 | gat
# Processing Record 30 of Set 14 | banda aceh
# Processing Record 31 of Set 14 | whittlesea
# Processing Record 32 of Set 14 | salinopolis
# Processing Record 33 of Set 14 | ejido
# Processing Record 34 of Set 14 | abu dhabi
# Processing Record 35 of Set 14 | kroya
# Processing Record 36 of Set 14 | belmonte
# Processing Record 37 of Set 14 | kirsanov
# Processing Record 38 of Set 14 | lappersdorf
# Processing Record 39 of Set 14 | valuyki
# Processing Record 40 of Set 14 | verkhnyaya inta
# Processing Record 41 of Set 14 | malanje
# Processing Record 42 of Set 14 | miguel hidalgo
# Processing Record 43 of Set 14 | kijang
# Processing Record 44 of Set 14 | djambala
# Processing Record 45 of Set 14 | petropavlovsk-kamchatskiy
# Processing Record 46 of Set 14 | takikawa
# Processing Record 47 of Set 14 | jamiltepec
# Processing Record 48 of Set 14 | aklavik
# Processing Record 49 of Set 14 | gillette
# Processing Record 50 of Set 14 | kasongo-lunda
# Processing Record 1 of Set 15 | hauterive
# Processing Record 2 of Set 15 | kamenskoye
# City not found. Skipping...
# Processing Record 3 of Set 15 | zapolyarnyy
# Processing Record 4 of Set 15 | thinadhoo
# Processing Record 5 of Set 15 | horadiz
# Processing Record 6 of Set 15 | ramhormoz
# Processing Record 7 of Set 15 | maningrida
# Processing Record 8 of Set 15 | karaul
# City not found. Skipping...
# Processing Record 9 of Set 15 | paciran
# Processing Record 10 of Set 15 | strezhevoy
# Processing Record 11 of Set 15 | ratnagiri
# Processing Record 12 of Set 15 | turukhansk
# Processing Record 13 of Set 15 | beneditinos
# Processing Record 14 of Set 15 | falmouth
# Processing Record 15 of Set 15 | pindwara
# Processing Record 16 of Set 15 | yuncheng
# Processing Record 17 of Set 15 | sahuaripa
# Processing Record 18 of Set 15 | chandbali
# Processing Record 19 of Set 15 | ostrovnoy
# Processing Record 20 of Set 15 | simao
# Processing Record 21 of Set 15 | puerto ayacucho
# Processing Record 22 of Set 15 | koumac
# Processing Record 23 of Set 15 | druzhba
# Processing Record 24 of Set 15 | kristiansand
# Processing Record 25 of Set 15 | ulagan
# Processing Record 26 of Set 15 | mezen
# Processing Record 27 of Set 15 | port-gentil
# Processing Record 28 of Set 15 | tawang
# Processing Record 29 of Set 15 | sangamner
# Processing Record 30 of Set 15 | sibolga
# Processing Record 31 of Set 15 | tekirdag
# Processing Record 32 of Set 15 | kemijarvi
# Processing Record 33 of Set 15 | inderborskiy
# City not found. Skipping...
# Processing Record 34 of Set 15 | kitimat
# Processing Record 35 of Set 15 | bayir
# Processing Record 36 of Set 15 | guanare
# Processing Record 37 of Set 15 | bethanien
# Processing Record 38 of Set 15 | fayaoue
# Processing Record 39 of Set 15 | dustlik
# Processing Record 40 of Set 15 | coahuayana
# Processing Record 41 of Set 15 | pimentel
# Processing Record 42 of Set 15 | lyubech
# Processing Record 43 of Set 15 | brownsville
# Processing Record 44 of Set 15 | la ronge
# Processing Record 45 of Set 15 | houma
# Processing Record 46 of Set 15 | coihueco
# Processing Record 47 of Set 15 | spirovo
# Processing Record 48 of Set 15 | sarangani
# Processing Record 49 of Set 15 | vologda
# Processing Record 50 of Set 15 | hurghada
# Processing Record 1 of Set 16 | gweta
# Processing Record 2 of Set 16 | rocha
# Processing Record 3 of Set 16 | iskateley
# Processing Record 4 of Set 16 | tinskoy
# Processing Record 5 of Set 16 | itaqui
# Processing Record 6 of Set 16 | los llanos de aridane
# Processing Record 7 of Set 16 | sur
# Processing Record 8 of Set 16 | liverpool
# Processing Record 9 of Set 16 | kampot
# Processing Record 10 of Set 16 | monrovia
# Processing Record 11 of Set 16 | mishan
# Processing Record 12 of Set 16 | portland
# Processing Record 13 of Set 16 | nicoya
# Processing Record 14 of Set 16 | tiarei
# Processing Record 15 of Set 16 | zarya
# Processing Record 16 of Set 16 | victoria point
# Processing Record 17 of Set 16 | taltal
# Processing Record 18 of Set 16 | mackenzie
# Processing Record 19 of Set 16 | aranos
# Processing Record 20 of Set 16 | minudasht
# Processing Record 21 of Set 16 | sola
# Processing Record 22 of Set 16 | bonavista
# Processing Record 23 of Set 16 | idlib
# Processing Record 24 of Set 16 | alice springs
# Processing Record 25 of Set 16 | kapuskasing
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 712

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Sinjar  36.3209   41.8754     64.94        27          44
# 1           Bluff -46.6000  168.3333     63.81        66          43
# 2         Iqaluit  63.7506  -68.5145     29.93       100         100
# 3  Port Elizabeth -33.9180   25.5701     59.09        96         100
# 4           Avera  33.1940  -82.5271     60.39        86         100
#
#    Wind Speed Country Weather Description
# 0        7.54      IQ    scattered clouds
# 1        3.80      NZ    scattered clouds
# 2       11.50      CA          light snow
# 3       11.50      ZA         shower rain
# 4        9.06      US     overcast clouds

# %%
# Display sample data
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Sinjar  36.3209   41.8754     64.94        27          44
# 1           Bluff -46.6000  168.3333     63.81        66          43
# 2         Iqaluit  63.7506  -68.5145     29.93       100         100
# 3  Port Elizabeth -33.9180   25.5701     59.09        96         100
# 4           Avera  33.1940  -82.5271     60.39        86         100
# 5            Hilo  19.7297 -155.0900     82.13        81           0
# 6        Masvingo -20.0637   30.8277     66.58        61          15
# 7           Uvira  -3.4067   29.1458     74.35        70          77
# 8        Takoradi   4.8845   -1.7554     78.21        83           2
# 9           Pevek  69.7008  170.3133      6.17        96         100
#
#    Wind Speed Country Weather Description
# 0        7.54      IQ    scattered clouds
# 1        3.80      NZ    scattered clouds
# 2       11.50      CA          light snow
# 3       11.50      ZA         shower rain
# 4        9.06      US     overcast clouds
# 5        8.05      US           clear sky
# 6        4.34      ZW          few clouds
# 7        1.52      CD       broken clouds
# 8        4.43      GH           clear sky
# 9        5.48      RU     overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Weather Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
cols = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Weather Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[cols]

# Display sample data
city_data_df.head()
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Sinjar      IQ  36.3209   41.8754     64.94        27          44
# 1           Bluff      NZ -46.6000  168.3333     63.81        66          43
# 2         Iqaluit      CA  63.7506  -68.5145     29.93       100         100
# 3  Port Elizabeth      ZA -33.9180   25.5701     59.09        96         100
# 4           Avera      US  33.1940  -82.5271     60.39        86         100
#
#    Wind Speed Weather Description
# 0        7.54    scattered clouds
# 1        3.80    scattered clouds
# 2       11.50          light snow
# 3       11.50         shower rain
# 4        9.06     overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Weather Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
fn = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(fn, index_label='City_ID')
