# %%
#6.3.1 module
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create a practice set of random latitude and longitude combinations.
lats = [25.12903645, 25.92017388, 26.62509167, -59.98969384, 37.30571269]
lngs = [-67.59741259, 11.09532135, 74.84233102, -76.89176677, -61.13376282]
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the print() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(coordinate[0], coordinate[1])
# Out:
# 25.12903645 -67.59741259
# 25.92017388 11.09532135
# 26.62509167 74.84233102
# -59.98969384 -76.89176677
# 37.30571269 -61.13376282

# %%
lats = [25.12903645, 25.92017388, 26.62509167, -59.98969384, 37.30571269]
lngs = [-67.59741259, 11.09532135, 74.84233102, -76.89176677, -61.13376282]
lat_lngs = zip(lats, lngs)

coordinates = list(lat_lngs)

for coordinate in coordinates:
    print(coordinate[0], coordinate[1])
# Out:
# 25.12903645 -67.59741259
# 25.92017388 11.09532135
# 26.62509167 74.84233102
# -59.98969384 -76.89176677
# 37.30571269 -61.13376282

# %%
print(list(coordinates))

import pprint
pp = pprint.PrettyPrinter()

pp.pprint(list(lat_lngs))
# Out:
# [(25.12903645, -67.59741259), (25.92017388, 11.09532135), (26.62509167, 74.84233102), (-59.98969384, -76.89176677), (37.30571269, -61.13376282)]
# []

# %%
from citipy import citipy

# %%
cities = []
# Identify the nearest city for each latitude and longitude combination.

for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    #if city is unique, then add to cities list
    if city not in cities:
        cities.append(city)

#print city county to confirm sufficient count.
len(cities)
print(cities)
# Out:
# ['cockburn town', 'gat', 'parvatsar', 'punta arenas', 'saint george']

# %%
import numpy as np

lats = np.random.uniform(-90, 90, 1500)
long = np.random.uniform(-180, 180, 1500)
lats_long = zip(lats, long)
lats_long

coordinates = list(lats_long)

print(coordinates)
# Out:
# [(83.94134641523098, 140.6521689175912), (74.2199275195837, 109.50403422178647), (70.7564389562211, 144.45644328195232), (11.157849676091814, -87.46889915515872), (-37.3900883947067, 50.0939363517642), (-82.13693476962008, 27.128116384136547), (41.88375191017832, -123.31122167569373), (-78.79985029346551, 139.16475261095587), (8.32991204889808, 30.07273404985787), (-37.318873543520056, 117.7441506568278), (64.79481491347693, -27.709658372822815), (-59.31178619328243, 21.482389727808822), (-6.767308660498713, 60.279151022381654), (89.9444897315974, -46.41759058993742), (-72.10788134508638, 55.175727109821594), (-14.933050682400363, 178.53182336789536), (-80.33157708610491, 46.31425134523499), (-32.50065929180452, -32.28188043404583), (60.043894879406224, 100.11193692583925), (-14.621357316962602, 159.7839790342867), (-65.61496463800012, -57.0952051544202), (-13.893526910933232, -144.08077426634733), (28.047676774397758, 35.426290221270534), (-25.930580150825023, 69.01544137272418), (-
# ...

# %%
cities = []

for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)
        
print(len(cities))
#print(cities)
# Out:
# 621

# %%
# for i in range(len(cities)):
#     print(i)

    
for i in cities:
    print(i, i.title())
    
    
# for i, x in enumerate(cities):
#     print(i, x)


# i=0
# for x in cities:
#     print(i, x)
#     i += 1
    
# for i in range(len(cities)):
#     print(i, cities[i])
# Out:
# nizhneyansk Nizhneyansk
# saskylakh Saskylakh
# belaya gora Belaya Gora
# san rafael del sur San Rafael Del Sur
# taolanaro Taolanaro
# bredasdorp Bredasdorp
# grants pass Grants Pass
# hobart Hobart
# ler Ler
# albany Albany
# olafsvik Olafsvik
# victoria Victoria
# upernavik Upernavik
# east london East London
# asau Asau
# port alfred Port Alfred
# arraial do cabo Arraial Do Cabo
# kodinsk Kodinsk
# kirakira Kirakira
# ushuaia Ushuaia
# tautira Tautira
# tabuk Tabuk
# bambous virieux Bambous Virieux
# saint-joseph Saint-Joseph
# new norfolk New Norfolk
# saint george Saint George
# hilo Hilo
# ambulu Ambulu
# mataura Mataura
# rikitea Rikitea
# kotka Kotka
# abhar Abhar
# qaanaaq Qaanaaq
# hithadhoo Hithadhoo
# ulaanbaatar Ulaanbaatar
# nuuk Nuuk
# bengkulu Bengkulu
# uroteppa Uroteppa
# lebu Lebu
# tasiilaq Tasiilaq
# zwedru Zwedru
# chunskiy Chunskiy
# tres palos Tres Palos
# verkhniy tagil Verkhniy Tagil
# carballo Carballo
# illoqqortoormiut Illoqqortoormiut
# ...

# %%
import time
from datetime import datetime

#create empty list to hold weather data

cities_data = []

#Print beginning of the logging
print("Beginning Data Retrieval     ")
print("-----------------------------")

# creat counters

record_count = 1
set_count = 1

# Loop through the list of cities

for i, city in enumerate(cities):
    #Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
    
    #Log the URL, record, and set numbers and the city
    print(f'Processing Record {record_count} of Set {set_count} | {city}')
    
    #Add 1 to the record count.
    record_count +=1
    
    #Create endpoint URL for each city
    #city_url = url + '&q=' + cities[i]
    city_url = url + '&q=' + city.replace(' ','+')
    
    # Run an API request for each of the cities.
    try:        
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        cities_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})
        
        print("City weather found")

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 2 of Set 1 | saskylakh
# City weather found
# Processing Record 3 of Set 1 | belaya gora
# City weather found
# Processing Record 4 of Set 1 | san rafael del sur
# City weather found
# Processing Record 5 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 6 of Set 1 | bredasdorp
# City weather found
# Processing Record 7 of Set 1 | grants pass
# City weather found
# Processing Record 8 of Set 1 | hobart
# City weather found
# Processing Record 9 of Set 1 | ler
# City weather found
# Processing Record 10 of Set 1 | albany
# City weather found
# Processing Record 11 of Set 1 | olafsvik
# City weather found
# Processing Record 12 of Set 1 | victoria
# City weather found
# Processing Record 13 of Set 1 | upernavik
# City weather found
# Processing Record 14 of Set 1 | east london
# City weather found
# ...

# %%
print(cities_data[1:])
# Out:
# [{'City': 'Belaya Gora', 'Lat': 68.5333, 'Lng': 146.4167, 'Max Temp': 10.78, 'Humidity': 87, 'Cloudiness': 100, 'Wind Speed': 6.49, 'Country': 'RU', 'Date': '2022-10-27 22:49:18'}, {'City': 'San Rafael Del Sur', 'Lat': 11.8485, 'Lng': -86.4384, 'Max Temp': 88.77, 'Humidity': 79, 'Cloudiness': 83, 'Wind Speed': 2.21, 'Country': 'NI', 'Date': '2022-10-27 22:49:19'}, {'City': 'Bredasdorp', 'Lat': -34.5322, 'Lng': 20.0403, 'Max Temp': 59.14, 'Humidity': 83, 'Cloudiness': 25, 'Wind Speed': 2.13, 'Country': 'ZA', 'Date': '2022-10-27 22:45:30'}, {'City': 'Grants Pass', 'Lat': 42.439, 'Lng': -123.3284, 'Max Temp': 63.46, 'Humidity': 51, 'Cloudiness': 0, 'Wind Speed': 9.22, 'Country': 'US', 'Date': '2022-10-27 22:49:20'}, {'City': 'Hobart', 'Lat': -42.8794, 'Lng': 147.3294, 'Max Temp': 58.26, 'Humidity': 97, 'Cloudiness': 100, 'Wind Speed': 8.05, 'Country': 'AU', 'Date': '2022-10-27 22:47:42'}, {'City': 'Ler', 'Lat': 8.3018, 'Lng': 30.1418, 'Max Temp': 74.17, 'Humidity': 67, 'Cloudiness': 15,
# ...

# %%
import pandas as pd

# %%
city_data_df = pd.DataFrame(cities_data)
city_data_df.head(10)
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Saskylakh  71.9167  114.0833     -1.12        99          85
# 1         Belaya Gora  68.5333  146.4167     10.78        87         100
# 2  San Rafael Del Sur  11.8485  -86.4384     88.77        79          83
# 3          Bredasdorp -34.5322   20.0403     59.14        83          25
# 4         Grants Pass  42.4390 -123.3284     63.46        51           0
# 5              Hobart -42.8794  147.3294     58.26        97         100
# 6                 Ler   8.3018   30.1418     74.17        67          15
# 7              Albany  42.6001  -73.9662     52.34        59           0
# 8            Olafsvik  64.8945  -23.7142     39.63        80          95
# 9            Victoria  22.2855  114.1577     75.38        78          14
#
#    Wind Speed Country                 Date
# 0        4.68      RU  2022-10-27 22:49:18
# 1        6.49      RU  2022-10-27 22:49:18
# ...

# %%
# re-ordering columns

city_weather_df = city_data_df[['City','Country','Date','Lat','Lng','Max Temp','Humidity','Cloudiness','Wind Speed']]

city_weather_df
# Out:
#                    City Country                 Date      Lat       Lng  \
# 0             Saskylakh      RU  2022-10-27 22:49:18  71.9167  114.0833
# 1           Belaya Gora      RU  2022-10-27 22:49:18  68.5333  146.4167
# 2    San Rafael Del Sur      NI  2022-10-27 22:49:19  11.8485  -86.4384
# 3            Bredasdorp      ZA  2022-10-27 22:45:30 -34.5322   20.0403
# 4           Grants Pass      US  2022-10-27 22:49:20  42.4390 -123.3284
# ..                  ...     ...                  ...      ...       ...
# 568               Hohoe      GH  2022-10-27 23:05:57   7.1518    0.4736
# 569          Ust-Omchug      RU  2022-10-27 23:05:58  61.1500  149.6333
# 570                Lamu      KE  2022-10-27 23:05:59  -2.2717   40.9020
# 571         Honningsvag      NO  2022-10-27 23:05:59  70.9821   25.9704
# 572         Brownsville      US  2022-10-27 23:05:59  25.9018  -97.4975
#
#      Max Temp  Humidity  Cloudiness  Wind Speed
# 0       -1.12        99          85        4.68
# ...

# %%
#conver to csv and export

city_weather_df.to_csv('cities.csv', index_label='City_ID')

# %%
city_weather_df.head()
# Out:
#                  City Country                 Date      Lat       Lng  \
# 0           Saskylakh      RU  2022-10-27 22:49:18  71.9167  114.0833
# 1         Belaya Gora      RU  2022-10-27 22:49:18  68.5333  146.4167
# 2  San Rafael Del Sur      NI  2022-10-27 22:49:19  11.8485  -86.4384
# 3          Bredasdorp      ZA  2022-10-27 22:45:30 -34.5322   20.0403
# 4         Grants Pass      US  2022-10-27 22:49:20  42.4390 -123.3284
#
#    Max Temp  Humidity  Cloudiness  Wind Speed
# 0     -1.12        99          85        4.68
# 1     10.78        87         100        6.49
# 2     88.77        79          83        2.21
# 3     59.14        83          25        2.13
# 4     63.46        51           0        9.22

# %%
import time

# get today's date in seconds
today = time.time()
today
# Out:
# 1666911960.943249

# %%
today = time.strftime('%x')
today
# Out:
# '10/27/22'

# %%
#extract variable from DF to be plotted

lat = city_weather_df['Lat']
max_temps = city_weather_df['Max Temp']
humidity = city_weather_df['Humidity']
cloudiness = city_weather_df['Cloudiness']
wind_speed = city_weather_df['Wind Speed']

# %%
import matplotlib
matplotlib.__version__
# Out:
# '3.5.2'

# %%
plt.scatter(lat,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig('Fig1.png')

plt.show()

# %%
plt.scatter(lat, humidity, edgecolor='black', linewidths=1, marker='o', alpha=0.8, label='Cities')
plt.title(f'City Latitude vs. Humidity'+time.strftime('%x'))
plt.ylabel('Humidity (%)')
plt.xlabel('Latitude')
plt.grid(True)


plt.savefig('Fig2.png')
plt.show()

# %%
plt.scatter(lat, cloudiness, edgecolor='black', linewidths=1, marker='o', alpha=0.8, label='Cities')
plt.title(f'City Latitude vs. Cloudiness(%)'+time.strftime('%x'))
plt.ylabel('Cloudiness (%)')
plt.xlabel('Latitude')
plt.grid(True)

plt.savefig('Fig3.png')
plt.show()

# %%
plt.scatter(lat, wind_speed, edgecolor='black', linewidths=1, marker='o', alpha=0.8, label='Cities')
plt.title(f'City Latitude vs. Wind Speed'+time.strftime('%x'))
plt.ylabel('Wind Speed')
plt.xlabel('Latitude')
plt.grid(True)

plt.savefig('Fig4.png')
plt.show()

# %%
# Practice using Linear Regression  ###########################

# %%
# importing dependencies < = linear regression from the scipy stats module

from scipy.stats import linregress

# %%
# 
lats = [42.5, 43.9, 8.1, 36.8, 79.9, 69.1, 25.7, 15.3, 12.7, 64.5]
temps = [80.5, 75.3, 90.9, 90.0, 40.4, 62.3, 85.4, 79.6, 72.5, 72.0]

linregress(lats, temps)
# Out:
# LinregressResult(slope=-0.452929121241496, intercept=92.93922548147363, rvalue=-0.7590444753769936, pvalue=0.01089687086168761, stderr=0.13734880392044935, intercept_stderr=6.372784691788096)

# %%
# perform linear regression

(slope, intercept, r_value, p_value, std_err) = linregress(lats, temps)

# get the equation of the line.

line_eq = 'y = '+str(round(slope,2)) +  'x + ' + str(round(intercept, 2))
print(line_eq)
print(f'The p_value is: {p_value}')
# Out:
# y = -0.45x + 92.94
# The p_value is: 0.01089687086168761

# %%
# calculate the regression line 'y values' from the slope and intercept.

regress_values = [(lat*slope+intercept) for lat in lats]
regress_values
# Out:
# [73.68973782871005,
#  73.05563705897195,
#  89.2704995994175,
#  76.27143381978658,
#  56.750188694278094,
#  61.64182320368626,
#  81.29894706556718,
#  86.00940992647874,
#  87.18702564170663,
#  63.72529716139714]

# %%
import matplotlib.pyplot as plt

# %%
# create scatter plat for x and y values
plt.scatter(lats, temps)

# plot the regression line with x-values and the y coords based on intercept and slope
plt.plot(lats, regress_values, 'r')

# annotate the text for the line equation and its coords
plt.annotate(line_eq, (10,40), fontsize=15, color='red')

plt.xlabel('Latitude')
plt.ylabel('Temp')
plt.show()

# %%
city_weather_df.head()
max_temp = city_weather_df['Max Temp']
wind_speed = city_weather_df['Wind Speed']

# %%
# perform linear regression (lat + max_temp)

(slope, intercept, r_value, p_value, std_err) = linregress(lat, max_temp)
linregress(lat, max_temp)

# calculate teh regression line 'y values' from the slope and intercept
regress_values = [(lat * slope + intercept) for x in lat]
regress_values

# Get the equation of the line.
line_eq = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))
print(line_eq)

# create a scatter plot of the x and y values
plt.scatter(lat, max_temp)

# plot the regression line with the x-values and the y coords based on the intercept and slope.
plt.plot(lat, regress_values,'r')

# annotate the text for the line equation and add it's coords
plt.annotate(line_eq, (10,0), fontsize=15, color='red')

plt.title('Temperature Correlation to Latitude')
plt.xlabel('Latitude')
plt.ylabel('Temperature')
plt.show()
# Out:
# y = -0.42x + 67.36

# %%
# perform linear regression (lat + humidity)

(slope, intercept, r_value, p_value, std_err) = linregress(lat, humidity)
linregress(lat, humidity)

# calculate teh regression line 'y values' from the slope and intercept
regress_values = [(lat * slope + intercept) for x in lat]
regress_values

# Get the equation of the line.
line_eq = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))
print(line_eq)

# create a scatter plot of the x and y values
plt.scatter(lat, humidity)

# plot the regression line with the x-values and the y coords based on the intercept and slope.
plt.plot(lat, regress_values,'r')

# annotate the text for the line equation and add it's coords
plt.annotate(line_eq, (10,10), fontsize=15, color='red')

plt.title('Humidity Correlation to Latitude')
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.show()
# Out:
# y = 0.09x + 71.64

# %%
# perform linear regression (lat + cloudiness)

(slope, intercept, r_value, p_value, std_err) = linregress(lat, cloudiness)
linregress(lat, cloudiness)

# calculate teh regression line 'y values' from the slope and intercept
regress_values = [(lat * slope + intercept) for x in lat]
regress_values

# Get the equation of the line.
line_eq = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))
print(line_eq)

# create a scatter plot of the x and y values
plt.scatter(lat, cloudiness)

# plot the regression line with the x-values and the y coords based on the intercept and slope.
plt.plot(lat, regress_values,'r')

# annotate the text for the line equation and add it's coords
plt.annotate(line_eq, (10,10), fontsize=15, color='red')

plt.title('Cloudiness Correlation to Latitude')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.show()
# Out:
# y = 0.27x + 49.28

# %%
# perform linear regression (lat + wind speed)

(slope, intercept, r_value, p_value, std_err) = linregress(lat, wind_speed)
linregress(lat, wind_speed)

# calculate teh regression line 'y values' from the slope and intercept
regress_values = [(lat * slope + intercept) for x in lat]
regress_values

# Get the equation of the line.
line_eq = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))
print(line_eq)

# create a scatter plot of the x and y values
plt.scatter(lat, wind_speed)

# plot the regression line with the x-values and the y coords based on the intercept and slope.
plt.plot(lat, regress_values,'r')

# annotate the text for the line equation and add it's coords
plt.annotate(line_eq, (10,0), fontsize=15, color='red')

plt.title('Wind Speed Correlation to Latitude')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.show()
# Out:
# y = 0.01x + 7.78

# %%
index13 = city_weather_df.loc[13]
index13
# Out:
# City                  Port Alfred
# Country                        ZA
# Date          2022-10-27 22:49:02
# Lat                      -33.5906
# Lng                        26.891
# Max Temp                    63.18
# Humidity                       93
# Cloudiness                     66
# Wind Speed                    3.0
# Name: 13, dtype: object

# %%
#city_data_df["Lat"] >= 0 <= returns bool (Ture or False) for each row

# code below returns a df w/all data
northern_hemi_df = city_weather_df.loc[(city_weather_df['Lat']) >= 0]
southern_hemi_df = city_weather_df.loc[(city_weather_df['Lat']) < 0]

# %%
southern_hemi_df.head()
#northern_hemi_df.head()
# Out:
#                City Country                 Date      Lat       Lng  Max Temp  \
# 3        Bredasdorp      ZA  2022-10-27 22:45:30 -34.5322   20.0403     59.14
# 5            Hobart      AU  2022-10-27 22:47:42 -42.8794  147.3294     58.26
# 11      East London      ZA  2022-10-27 22:48:18 -33.0153   27.9116     66.97
# 13      Port Alfred      ZA  2022-10-27 22:49:02 -33.5906   26.8910     63.18
# 14  Arraial Do Cabo      BR  2022-10-27 22:47:51 -22.9661  -42.0278     76.86
#
#     Humidity  Cloudiness  Wind Speed
# 3         83          25        2.13
# 5         97         100        8.05
# 11        76         100       15.50
# 13        93          66        3.00
# 14        83           0       16.11

# %%
# Import linregress
from scipy.stats import linregress

# Create a function to create perform linear regression on the weather data
# and plot a regression line and the equation with the data.
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):

    # Run regression on hemisphere weather data.
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

    # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    # Get the equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    # Create a scatter plot and plot the regression line.
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.title(title)
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.show()

# %%
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]

(slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)
linregress(x_values, y_values)
# Out:
# LinregressResult(slope=-0.9441627280496829, intercept=90.81951389859725, rvalue=-0.8588859933791669, pvalue=8.405277943647868e-115, stderr=0.028582940676005045, intercept_stderr=1.2846334066388538)

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]

# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere for Maximum Temperature', 'Max Temp',(10,40))

# %%
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]

(slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)
linregress(x_values, y_values)
# Out:
# LinregressResult(slope=0.49894284666716243, intercept=81.18235746655776, rvalue=0.66562927865425, pvalue=8.746424967026774e-25, stderr=0.041579799475137, intercept_stderr=1.02125536022424)

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,'Linear Regression on the Southern Hemisphere for Maximum Temperature', 
                       'Max Temp',(-50,90))

# %%
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]

(slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)
linregress(x_values, y_values)
# Out:
# LinregressResult(slope=0.24225705384541568, intercept=64.26450668655642, rvalue=0.23968619084232978, pvalue=1.6828098583589107e-06, stderr=0.049816117374201184, intercept_stderr=2.238938578550957)

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere for % Humidity', '% Humidity',(40,10))

# %%
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]

(slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)
linregress(x_values, y_values)
# Out:
# LinregressResult(slope=0.22561152714428737, intercept=77.10897771896548, rvalue=0.18227874892484566, pvalue=0.013524500848532371, stderr=0.09045832517171559, intercept_stderr=2.2217771760482368)

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere for % Humidity', '% Humidity',(-40,10))

# %%
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]

(slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)
linregress(x_values, y_values)
# Out:
# LinregressResult(slope=0.6937844353519399, intercept=29.1186872297587, rvalue=0.34669946185059425, pvalue=1.861778391934689e-12, stderr=0.09529001018970464, intercept_stderr=4.282719955102976)

# %%
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere for % Cloudiness', '% Cloudiness',
                       (10,60))

# %%
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]

(slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)
linregress(x_values, y_values)
# Out:
# LinregressResult(slope=0.3934984191545674, intercept=58.51456193659987, rvalue=0.13602742383922178, pvalue=0.06634589054793191, stderr=0.21302060694591748, intercept_stderr=5.2320703665688475)

# %%
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere for % Cloudiness', '% Cloudiness',
                       (-50,60))

# %%
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]

(slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)
linregress(x_values, y_values)
# Out:
# LinregressResult(slope=0.06817790052666563, intercept=5.067834262237122, rvalue=0.2506482114104783, pvalue=5.32315940306663e-07, stderr=0.01336822073602491, intercept_stderr=0.6008221176219473)

# %%
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere for Wind Speed', 'Wind Speed (mph)',
                       (40,20))

# %%
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]

(slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)
linregress(x_values, y_values)
# Out:
# LinregressResult(slope=-0.12919511184988322, intercept=5.496899172900816, rvalue=-0.30402222934996287, pvalue=2.8639042657675472e-05, stderr=0.030091347581639675, intercept_stderr=0.7390836512450253)

# %%
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere for Wind Speed', 'Wind Speed (mph)',
                       (-50,20))

# %%
# Out:
#   Input In [173]
#     jupyter nbextension enable --py --sys-prefix widgetsnbextension
#             ^
# SyntaxError: invalid syntax

# %%
$ jupyter nbextension enable --py --sys-prefix widgetsnbextension
# Out:
#   Input In [174]
#     $ jupyter nbextension enable --py --sys-prefix widgetsnbextension
#     ^
# SyntaxError: invalid syntax

# %%
pip install gmaps
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
